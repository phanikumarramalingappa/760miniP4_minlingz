# %% [markdown]
# Connected to my-env (Python 3.11.5)

# %% [markdown]
# # Descript statistics Jupiter notebook

# %%
import matplotlib.pyplot as plt
import lib

# %%
# Read csv file
data = lib.read_csv_file("world-small.csv")

# %%
# convert column to integer
data["gdppcap08"] = data["gdppcap08"].astype("int")

# %%
# scatter plot visualization
data.plot.scatter(x="gdppcap08", y="polityIV", alpha=0.5)
plt.savefig("plot.png")
plt.show()

# %%
# return statistics summary
summary = lib.generate_statistics_summary(data[["gdppcap08", "polityIV"]])
# Out:
#           gdppcap08    polityIV
# count    145.000000  145.000000
# mean   13251.993103   13.407816
# std    14802.581676    6.587626
# min      188.000000    0.000000
# 25%     2153.000000    7.666667
# 50%     7271.000000   16.000000
# 75%    19330.000000   19.000000
# max    85868.000000   20.000000
